# %% [markdown]
# # 04 — Retrieval Evaluation
#
# 20 known-answer Q&A pairs against the indexed filings.
# CI gate: **Recall@5 ≥ 0.75**, **MRR ≥ 0.60**.
#
# **Phase 4 deliverable.**

# %%
# TODO after Phase 4:
# Load 20 gold Q&A pairs from tests/fixtures/eval_qa.json
# Run hybrid retrieval for each question
# Compute Recall@5 and MRR
# assert recall_at_5 >= 0.75, f'Recall@5 {recall_at_5:.2f} below threshold'
# assert mrr >= 0.60, f'MRR {mrr:.2f} below threshold'
