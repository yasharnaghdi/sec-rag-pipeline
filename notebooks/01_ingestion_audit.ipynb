# %% [markdown]
# # 01 — Ingestion Audit
#
# Auditable walkthrough: download a real SEC DEF 14A → parse with SECProxyParser → inspect blocks.
#
# **This notebook is a Phase 1 deliverable.** Fill in the TODOs below after implementing `SECProxyParser`.

# %%
# TODO: download real DEF 14A via EdgarDownloader
# from ingestion.edgar_downloader import EdgarDownloader
# dl = EdgarDownloader()
# html_path, filing_meta = dl.download_proxy_filing(cik='0000320193', year=2023)  # Apple

# %%
# TODO: parse and inspect
# from ingestion.sec_proxy_parser import SECProxyParser
# parser = SECProxyParser()
# blocks = parser.parse_with_metadata(html_path, filing_meta)
# print(f'Total blocks: {len(blocks)}')
# section_headers = {b.section_header for b in blocks if b.section_header}
# print('Detected sections:', section_headers)
