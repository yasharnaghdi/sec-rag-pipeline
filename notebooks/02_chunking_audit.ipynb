# %% [markdown]
# # 02 — Chunking Audit
#
# Visualise: raw SEC blocks → chunks → token distribution → table boundary detection.
#
# **Phase 2 deliverable.** This replaces the black-box trust assumption with an auditable artifact.

# %%
# TODO after Phase 2:
# from chunking.splitter import SECChunker
# chunker = SECChunker()
# chunks = chunker.chunk_blocks(blocks)  # blocks from notebook 01
# token_counts = [c.token_count for c in chunks]
# table_chunks = [c for c in chunks if c.chunk_type == 'table']
# print(f'Total chunks: {len(chunks)}, Tables: {len(table_chunks)}')
# assert all(c.table_json is not None for c in table_chunks), 'Missing table_json!'
